# %% [markdown]
# <h1 style="font-family:verdana"> Capstone Project-Intro</h1>

# %% [markdown]
# <p><b>Introduction:</b></p>
# <p>There are many people we know including me, who indulge art. We always would love to have a certain guidance or poiters to some of the places with great and popular art across the world.</p>
#   </p>  let's go through all cities across globe and pick out the art venues.Cluster these palces and reveal the most famous art places to visit.One might find this information analysis helpful while during their travelling.</p>

# %% [markdown]
# <p><b>Interest:</b></p>
# <p>Travellers might be interested in using such clustering analysis to easily decide or prioritize their route map of art venues.</p>
